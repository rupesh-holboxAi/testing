# %%
import time
import random
import string
import requests
import hmac
import hashlib
import base64
import urllib.parse

# Consumer and Token Information
consumer_key = "FD0A617EAD11499C97C806F06FB4CBCD"
consumer_secret = "B091220B9B5342A78D592E991C41322A"
token_value = "AAA4E5969A3A450F978A9192A3C96C04"
token_secret = "BCC0C30CD7144713B83F10CA24AB58BC"

# API Endpoint
url = "https://api.bricklink.com/api/store/v1/orders"
direction = "in"

# Helper function to create the OAuth signature
def generate_oauth_signature(http_method, base_url, params, consumer_secret, token_secret):
    # Step 1: Encode the parameters and sort them by key
    sorted_params = sorted(params.items())
    encoded_params = urllib.parse.urlencode(sorted_params, safe="")

    # Step 2: Create the signature base string
    signature_base_string = "&".join([
        http_method,
        urllib.parse.quote(base_url, safe=""),
        urllib.parse.quote(encoded_params, safe="")
    ])

    # Step 3: Create the signing key
    signing_key = f"{urllib.parse.quote(consumer_secret, safe='')}&{urllib.parse.quote(token_secret, safe='')}"

    # Step 4: Create the HMAC-SHA1 signature
    hashed = hmac.new(signing_key.encode(), signature_base_string.encode(), hashlib.sha1)
    oauth_signature = base64.b64encode(hashed.digest()).decode()

    return oauth_signature

# Generating OAuth parameters
http_method = "GET"
timestamp = str(int(time.time()))
nonce = ''.join(random.choices(string.ascii_letters + string.digits, k=16))

oauth_params = {
    "oauth_consumer_key": consumer_key,
    "oauth_token": token_value,
    "oauth_signature_method": "HMAC-SHA1",
    "oauth_timestamp": timestamp,
    "oauth_nonce": nonce,
    "oauth_version": "1.0",
}

# Adding extra parameters (if any) for the request
extra_params = {
    "direction": direction
}

# Merge OAuth and extra parameters for signature generation
all_params = {**oauth_params, **extra_params}

# Generate the OAuth signature
oauth_signature = generate_oauth_signature(http_method, url, all_params, consumer_secret, token_secret)
oauth_params["oauth_signature"] = oauth_signature

# Build the Authorization header from the OAuth parameters
auth_header = "OAuth " + ", ".join([f'{k}="{urllib.parse.quote(v)}"' for k, v in oauth_params.items()])

# Make the request to the API
headers = {"Authorization": auth_header}
response = requests.get(url, headers=headers, params=extra_params)

# Print the response
if response.status_code == 200:
    print("API Response:")
    print(response.json())
else:
    print(f"Failed to fetch data. Status Code: {response.status_code}")
    print(response.text)
# Out:
# API Response:
# {'meta': {'description': 'OK', 'message': 'OK', 'code': 200}, 'data': []}

# %%
import time
import random
import string
import requests
import hmac
import hashlib
import base64
import urllib.parse

# Consumer and Token Information
consumer_key = "FD0A617EAD11499C97C806F06FB4CBCD"
consumer_secret = "B091220B9B5342A78D592E991C41322A"
token_value = "AAA4E5969A3A450F978A9192A3C96C04"
token_secret = "BCC0C30CD7144713B83F10CA24AB58BC"

# API Endpoint
url = "https://api.bricklink.com/api/store/v1/inventories"
direction = "in"

# Helper function to create the OAuth signature
def generate_oauth_signature(http_method, base_url, params, consumer_secret, token_secret):
    # Step 1: Encode the parameters and sort them by key
    sorted_params = sorted(params.items())
    encoded_params = urllib.parse.urlencode(sorted_params, safe="")

    # Step 2: Create the signature base string
    signature_base_string = "&".join([
        http_method,
        urllib.parse.quote(base_url, safe=""),
        urllib.parse.quote(encoded_params, safe="")
    ])

    # Step 3: Create the signing key
    signing_key = f"{urllib.parse.quote(consumer_secret, safe='')}&{urllib.parse.quote(token_secret, safe='')}"

    # Step 4: Create the HMAC-SHA1 signature
    hashed = hmac.new(signing_key.encode(), signature_base_string.encode(), hashlib.sha1)
    oauth_signature = base64.b64encode(hashed.digest()).decode()

    return oauth_signature

# Generating OAuth parameters
http_method = "GET"
timestamp = str(int(time.time()))
nonce = ''.join(random.choices(string.ascii_letters + string.digits, k=16))

oauth_params = {
    "oauth_consumer_key": consumer_key,
    "oauth_token": token_value,
    "oauth_signature_method": "HMAC-SHA1",
    "oauth_timestamp": timestamp,
    "oauth_nonce": nonce,
    "oauth_version": "1.0",
}

# Adding extra parameters (if any) for the request
extra_params = {
    "direction": direction
}

# Merge OAuth and extra parameters for signature generation
all_params = {**oauth_params, **extra_params}

# Generate the OAuth signature
oauth_signature = generate_oauth_signature(http_method, url, all_params, consumer_secret, token_secret)
oauth_params["oauth_signature"] = oauth_signature

# Build the Authorization header from the OAuth parameters
auth_header = "OAuth " + ", ".join([f'{k}="{urllib.parse.quote(v)}"' for k, v in oauth_params.items()])

# Make the request to the API
headers = {"Authorization": auth_header}
response = requests.get(url, headers=headers, params=extra_params)

# Print the response
if response.status_code == 200:
    print("API Response:")
    print(response.json())
else:
    print(f"Failed to fetch data. Status Code: {response.status_code}")
    print(response.text)
# Out:
# API Response:
# ...
